# %% [markdown]
# # Related subjects
# ## 1st step: subject frequency
#
# In this step we're going to analyse the most frequent subjects in the links of a People page

# %% [markdown]
# ### Preprocessing

# %%
import pandas as pd
import numpy as np
from urllib.parse import unquote
import matplotlib.pyplot as plt

# %%
# Download the datasets 
folder_path = "dataset/wikispeedia_paths-and-graph/"
file_paths = ["paths_finished.tsv", "paths_unfinished.tsv", "categories.tsv", "articles.tsv", "links.tsv"]
data_frames_names = ["paths_finished", "paths_unfinished", "categories", "article", "links"]
dfs_headers = [
    ["hashedIpAddress", "timestamp", "durationInSec", "path", "rating"],
    ["hashedIpAddress", "timestamp", "durationInSec", "path", "target", "type"],
    ["article", "category"],
    ["article"],
    ["linkSource", "linkTarget"]
]
dfs_skiprows = [16, 17, 13, 12, 12]
dfs = {}

for i in range(len(file_paths)):
    dfs[data_frames_names[i]] = pd.read_csv(folder_path + file_paths[i], sep='\t', header=None, names=dfs_headers[i], skiprows=range(dfs_skiprows[i]))

# %%
categories = dfs["categories"]
links = dfs["links"]

# %%
def change_characters(dataframe, dataset_name, column_name):
    dataframe[dataset_name][column_name] = [unquote(art) for art in dataframe[dataset_name][column_name]]
    return dataframe

# %%
dfs = change_characters(dfs, 'categories', 'article')
dfs = change_characters(dfs, 'categories', 'category')
dfs = change_characters(dfs, 'links', 'linkSource')
dfs = change_characters(dfs, 'links', 'linkTarget')

# %%
#first copy the data_frame
reduced_categories = categories.copy(deep=True)

#extract the reduced categories and add them to the copied df
reduced_categories_list = [category.replace('subject.', '').split('.')[0] for category in reduced_categories['category']]
reduced_categories = reduced_categories.assign(simple_category = reduced_categories_list)

# %% [markdown]
# ### Links going from People

# %%
#reduce the rows of the lnks dataframe by creating a list of outgoing links
links_from_article = links.groupby('linkSource')['linkTarget'].agg(list).reset_index()
links_from_article.columns = ['article', 'links']
links_from_article
#merge it with reduced_categories to get a fuller dataframe
links_from_article = pd.merge(reduced_categories, links_from_article, on='article', how='inner')
links_from_article
# Out:
#                 article                                           category  \
# 0     Áedán_mac_Gabráin  subject.History.British_History.British_Histor...
# 1     Áedán_mac_Gabráin                  subject.People.Historical_figures
# 2                 Åland                                  subject.Countries
# 3                 Åland  subject.Geography.European_Geography.European_...
# 4         Édouard_Manet                             subject.People.Artists
# ...                 ...                                                ...
# 5185          Zirconium        subject.Science.Chemistry.Chemical_elements
# 5186          Zoroaster       subject.People.Religious_figures_and_leaders
# 5187       Zuid-Gelders               subject.Geography.European_Geography
# 5188       Zuid-Gelders          subject.Language_and_literature.Languages
# 5189               Zulu                subject.Geography.African_Geography
#
#               simple_category  \
# 0                     History
# 1                      People
# 2                   Countries
# 3                   Geography
# 4                      People
# ...                       ...
# 5185                  Science
# 5186                   People
# 5187                Geography
# 5188  Language_and_literature
# 5189                Geography
#
#                                                   links
# 0     [Bede, Columba, Dál_Riata, Great_Britain, Irel...
# 1     [Bede, Columba, Dál_Riata, Great_Britain, Irel...
# 2     [20th_century, Baltic_Sea, Crimean_War, Curren...
# 3     [20th_century, Baltic_Sea, Crimean_War, Curren...
# 4     [Absinthe, Beer, Claude_Monet, Diego_Velázquez...
# ...                                                 ...
# 5185  [Aluminium, Arabic_language, Australia, Bicycl...
# 5186  [18th_century, 9th_century, Afghanistan, Age_o...
# 5187  [Brabantian, Dutch_language, East_Flemish, Hol...
# 5188  [Brabantian, Dutch_language, East_Flemish, Hol...
# 5189  [AK-47, Bantu, Cape_Town, Christianity, Englis...
#
# [5190 rows x 4 columns]

# %%
def find_top_categories(article_list):
    
    article_categories = reduced_categories[reduced_categories['article'].isin(article_list)]['simple_category']
    top_categories = article_categories.value_counts().nlargest(3).index.tolist()
    top_categories += [None] * (3 - len(top_categories))
    return pd.Series(top_categories)

# %%
outgoing_subjects = links_from_article.copy(deep=True)
outgoing_subjects[['top_category1', 'top_category2', 'top_category3']] = links_from_article['links'].apply(find_top_categories)
outgoing_subjects.drop(columns=['links'], inplace=True)
outgoing_subjects
# Out:
#                 article                                           category  \
# 0     Áedán_mac_Gabráin  subject.History.British_History.British_Histor...
# 1     Áedán_mac_Gabráin                  subject.People.Historical_figures
# 2                 Åland                                  subject.Countries
# 3                 Åland  subject.Geography.European_Geography.European_...
# 4         Édouard_Manet                             subject.People.Artists
# ...                 ...                                                ...
# 5185          Zirconium        subject.Science.Chemistry.Chemical_elements
# 5186          Zoroaster       subject.People.Religious_figures_and_leaders
# 5187       Zuid-Gelders               subject.Geography.European_Geography
# 5188       Zuid-Gelders          subject.Language_and_literature.Languages
# 5189               Zulu                subject.Geography.African_Geography
#
#               simple_category            top_category1 top_category2  \
# 0                     History                Geography       History
# 1                      People                Geography       History
# 2                   Countries                Geography   Citizenship
# 3                   Geography                Geography   Citizenship
# 4                      People                Geography        People
# ...                       ...                      ...           ...
# 5185                  Science                  Science     Geography
# 5186                   People                   People     Geography
# 5187                Geography  Language_and_literature     Geography
# 5188  Language_and_literature  Language_and_literature     Geography
# 5189                Geography                Geography     Countries
#
#      top_category3
# 0      Citizenship
# 1      Citizenship
# 2        Countries
# 3        Countries
# 4        Countries
# ...            ...
# 5185     Countries
# 5186     Countries
# 5187          None
# 5188          None
# 5189       History
#
# [5190 rows x 6 columns]

# %%
subjects_from_people = outgoing_subjects[outgoing_subjects.simple_category == 'People'].copy(deep=True)
subjects_from_people.drop(columns=['simple_category'], inplace=True)
subjects_from_people.value_counts('top_category1', normalize=True)
# Out:
# top_category1
# Geography                  0.631350
# People                     0.127721
# History                    0.085631
# Science                    0.065312
# Everyday_life              0.020319
# Religion                   0.020319
# Language_and_literature    0.018868
# Citizenship                0.010160
# Countries                  0.008708
# IT                         0.005806
# Mathematics                0.002903
# Music                      0.002903
# Name: proportion, dtype: float64

# %% [markdown]
# We can see that with this classification, we get that 63% of people that are related to Geography, which is very unlikely.

# %% [markdown]
# ### Links going to People
# Now we can do the same thing with only articles leading to a People page.

# %%
#reduce the rows of the lnks dataframe by creating a list of outgoing links
links_to_article = links.groupby('linkTarget')['linkSource'].agg(list).reset_index()
links_to_article = links_to_article.rename(columns={"linkTarget": "article", "linkSource": "source"}).copy(deep=True)
#merge it with reduced_categories to get a fuller dataframe
links_to_article = pd.merge(reduced_categories, links_to_article, on='article', how='inner')
links_to_article
# Out:
#            article                                      category  \
# 0     10th_century               subject.History.General_history
# 1     11th_century               subject.History.General_history
# 2     12th_century               subject.History.General_history
# 3     13th_century               subject.History.General_history
# 4     14th_century               subject.History.General_history
# ...            ...                                           ...
# 4712     Zirconium   subject.Science.Chemistry.Chemical_elements
# 4713     Zoroaster  subject.People.Religious_figures_and_leaders
# 4714  Zuid-Gelders          subject.Geography.European_Geography
# 4715  Zuid-Gelders     subject.Language_and_literature.Languages
# 4716          Zulu           subject.Geography.African_Geography
#
#               simple_category  \
# 0                     History
# 1                     History
# 2                     History
# 3                     History
# 4                     History
# ...                       ...
# 4712                  Science
# 4713                   People
# 4714                Geography
# 4715  Language_and_literature
# 4716                Geography
#
#                                                  source
# 0     [11th_century, 12th_century, 15th_century, 16t...
# 1     [10th_century, 12th_century, 15th_century, 16t...
# 2     [11th_century, 13th_century, 15th_century, 16t...
# 3     [11th_century, 12th_century, 14th_century, 15t...
# 4     [11th_century, 12th_century, 13th_century, 15t...
# ...                                                 ...
# 4712  [Calcium, Cerium, Diamond_simulant, Gas_metal_...
# 4713  [Friedrich_Nietzsche, Greco-Buddhism, Iran, Ir...
# 4714  [Brabantian, Dutch_language, East_Flemish, Hol...
# 4715  [Brabantian, Dutch_language, East_Flemish, Hol...
# 4716  [19th_century, Africa, History_of_South_Africa...
#
# [4717 rows x 4 columns]

# %%
ingoing_subjects = links_to_article.copy(deep=True)
ingoing_subjects[['top_category1', 'top_category2', 'top_category3']] = links_to_article['source'].apply(find_top_categories)
ingoing_subjects.drop(columns=['source'], inplace=True)
ingoing_subjects
# Out:
#            article                                      category  \
# 0     10th_century               subject.History.General_history
# 1     11th_century               subject.History.General_history
# 2     12th_century               subject.History.General_history
# 3     13th_century               subject.History.General_history
# 4     14th_century               subject.History.General_history
# ...            ...                                           ...
# 4712     Zirconium   subject.Science.Chemistry.Chemical_elements
# 4713     Zoroaster  subject.People.Religious_figures_and_leaders
# 4714  Zuid-Gelders          subject.Geography.European_Geography
# 4715  Zuid-Gelders     subject.Language_and_literature.Languages
# 4716          Zulu           subject.Geography.African_Geography
#
#               simple_category            top_category1          top_category2  \
# 0                     History                  History              Geography
# 1                     History                  History              Geography
# 2                     History                  History              Geography
# 3                     History                  History              Geography
# 4                     History                  History              Geography
# ...                       ...                      ...                    ...
# 4712                  Science                  Science  Design_and_Technology
# 4713                   People                   People               Religion
# 4714                Geography  Language_and_literature              Geography
# 4715  Language_and_literature  Language_and_literature              Geography
# 4716                Geography                Geography              Countries
#
#      top_category3
# 0        Countries
# 1        Countries
# 2        Countries
# 3         Religion
# 4        Countries
# ...            ...
# 4712          None
# 4713     Geography
# 4714          None
# 4715          None
# 4716       History
#
# [4717 rows x 6 columns]

# %%
subjects_to_people = ingoing_subjects[ingoing_subjects.simple_category == 'People'].copy(deep=True)
subjects_to_people.drop(columns=['simple_category'], inplace=True)
subjects_to_people.value_counts('top_category1', normalize=True)
# Out:
# top_category1
# People                     0.368760
# History                    0.222222
# Geography                  0.099839
# Science                    0.072464
# Everyday_life              0.043478
# Language_and_literature    0.038647
# Religion                   0.038647
# Music                      0.025765
# Art                        0.024155
# Citizenship                0.022544
# IT                         0.016103
# Design_and_Technology      0.011272
# Mathematics                0.008052
# Countries                  0.004831
# Business_Studies           0.003221
# Name: proportion, dtype: float64

# %% [markdown]
# This representation seem way more convicing as the distribution is more even.

# %%
subjects_to_people
# Out:
#               article                                      category  \
# 76        Abel_Tasman      subject.People.Geographers_and_explorers
# 85    Abraham_Lincoln                 subject.People.USA_Presidents
# 107        Adam_Smith             subject.People.Historical_figures
# 111      Adolf_Hitler               subject.People.Political_People
# 131         Agamemnon             subject.People.Historical_figures
# ...               ...                                           ...
# 4701       Zhang_Qian             subject.People.Historical_figures
# 4703         Zheng_He             subject.People.Historical_figures
# 4704      Ziad_Jarrah             subject.People.Historical_figures
# 4710          Zionism               subject.People.Political_People
# 4713        Zoroaster  subject.People.Religious_figures_and_leaders
#
#      top_category1     top_category2 top_category3
# 76       Geography         Countries        People
# 85          People         Geography       History
# 107    Citizenship  Business_Studies        People
# 111        History            People     Geography
# 131        History          Religion        People
# ...            ...               ...           ...
# 4701       History         Geography          None
# 4703     Geography           History     Countries
# 4704       History              None          None
# 4710        People         Geography       History
# 4713        People          Religion     Geography
#
# [621 rows x 5 columns]

# %%
perofrmers = subjects_to_people[subjects_to_people.category == "subject.People.Producers_directors_and_media_figures"].copy(deep=True)

# %%
perofrmers
# Out:
#                     article  \
# 145          Akira_Kurosawa
# 171        Alfred_Hitchcock
# 334   Arnold_Schwarzenegger
# 1171     David_Attenborough
# 4065          Sydney_Newman
# 4508            Walt_Disney
#
#                                                category  top_category1  \
# 145   subject.People.Producers_directors_and_media_f...  Everyday_life
# 171   subject.People.Producers_directors_and_media_f...         People
# 334   subject.People.Producers_directors_and_media_f...         People
# 1171  subject.People.Producers_directors_and_media_f...      Geography
# 4065  subject.People.Producers_directors_and_media_f...  Everyday_life
# 4508  subject.People.Producers_directors_and_media_f...         People
#
#       top_category2          top_category3
# 145            None                   None
# 171   Everyday_life  Design_and_Technology
# 334   Everyday_life                History
# 1171         People              Countries
# 4065           None                   None
# 4508  Everyday_life              Geography

# %% [markdown]
# ### TF-IDF

# %%
links_to_people  = ingoing_subjects[ingoing_subjects.simple_category == 'People'].copy(deep=True)

# %%
links_to_people
# Out:
#               article                                      category  \
# 76        Abel_Tasman      subject.People.Geographers_and_explorers
# 85    Abraham_Lincoln                 subject.People.USA_Presidents
# 107        Adam_Smith             subject.People.Historical_figures
# 111      Adolf_Hitler               subject.People.Political_People
# 131         Agamemnon             subject.People.Historical_figures
# ...               ...                                           ...
# 4701       Zhang_Qian             subject.People.Historical_figures
# 4703         Zheng_He             subject.People.Historical_figures
# 4704      Ziad_Jarrah             subject.People.Historical_figures
# 4710          Zionism               subject.People.Political_People
# 4713        Zoroaster  subject.People.Religious_figures_and_leaders
#
#      simple_category top_category1     top_category2 top_category3
# 76            People     Geography         Countries        People
# 85            People        People         Geography       History
# 107           People   Citizenship  Business_Studies        People
# 111           People       History            People     Geography
# 131           People       History          Religion        People
# ...              ...           ...               ...           ...
# 4701          People       History         Geography          None
# 4703          People     Geography           History     Countries
# 4704          People       History              None          None
# 4710          People        People         Geography       History
# 4713          People        People          Religion     Geography
#
# [621 rows x 6 columns]

# %%
# Create the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the documents
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# Get feature names (terms)
feature_names = tfidf_vectorizer.get_feature_names_out()
